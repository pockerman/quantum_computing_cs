# %% [markdown]
# # Quantum Fourier Transform

# %% [markdown]
# * [Overview](#overview)
# * [Quantum Fourier transform](#ekf)
# * [References](#refs)

# %% [markdown]
# ## <a name="overview"></a> Overview

# %% [markdown]
# In this section we discuss <a hre="https://en.wikipedia.org/wiki/Quantum_Fourier_transform">quantum Fourier transform</a> or QFT. The QFT is used in Shor's algorithm. The following video gives a high level overview of QFT.

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('mAHC1dWKNYE', width=800, height=300)

# %% [markdown]
# The following video gives a much more detailed presentation of QFT

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('pq2jkfJlLmY', width=800, height=300)

# %% [markdown]
# ## <a name="ekf"></a> Quantum Fourier transform

# %% [markdown]
# The classical Fourier transform is as follows

# %% [markdown]
# So what is QFT?  QFT is effectively a change of basis; from the computational basis to the so called Fourier basis.

# %% [markdown]
# We already know what is the computational basis. For a one qubit system this is just the set $\{|0\rangle, |1\rangle \}$. Similarly, for one qubit system, the Fourier basis is the set $\{|+\rangle, |-\rangle \}$

# %% [markdown]
# The Fourier transform for the zero and one basis vectors are denoted by $\tilde{|0\rangle}$, $\tilde{|1\rangle}$.

# %% [markdown]
# ## References

# %% [markdown]
# 1. Noson S. Yanofsky and Mirco A. Mannucci, ```Quantum Computing for Computer Scientists```, Cambridge University Press
# 2. Eleanor Rieffel, Wolfgang Polak, ```Quantum Computing: A Gentle Introduction```, The MIT Press.
# 3. <a href="https://en.wikipedia.org/wiki/Deutsch%E2%80%93Jozsa_algorithm">Deutsch's algorithm</a>
